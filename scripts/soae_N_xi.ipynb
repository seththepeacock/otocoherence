# %%
import os
import phaseco as pc
import numpy as np
import pandas as pd

dir_otocoh = r"c:\\Users\\setht\\Dropbox\\Citadel\\GitHub\\otocoherence"
dir_scripts = os.path.join(dir_otocoh, "scripts")
dir_results = os.path.join(dir_otocoh, "results")

os.chdir(dir_scripts)
from helper_funcs import *
os.chdir(dir_otocoh)
# Out:
# 'c:\\Users\\setht\\Dropbox\\Citadel\\GitHub\\otocoherence\\scripts'

# %%
speciess = ['Anole', 'Tokay', 'Human', 'Owl']
speciess = ['Anole']
wf_idxs = [0]
wf_len_s = 60

# Parameters
tau_s_psd = 0.5


for species in speciess:
    for wf_idx in wf_idxs:
        wf, wf_fn, fs, gpi, bpi = get_wf(species=species, wf_idx=wf_idx)
        wf = crop_wf(wf, fs, wf_len_s)
